# %%
#                                         creating own dataset
import cv2
import os
cam = cv2.VideoCapture(0)
face_detector = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
face_id = 2
count = 0

while(True):
    _, image_frame = cam.read()
    gray = cv2.cvtColor(image_frame, cv2.COLOR_BGR2GRAY)
    faces = face_detector.detectMultiScale(gray, 1.3, 5)
    for (x,y,w,h) in faces:
        cv2.rectangle(image_frame, (x,y), (x+w,y+h), (255,0,0), 2)
        count += 1
        cv2.imwrite("C:/Users/manoj/LW_MLOpps/TASKS/task_6/Training_data/person." + str(face_id) + '.' + str(count) + ".jpg", gray[y:y+h,x:x+w])
        cv2.imshow('frame', image_frame)

    if cv2.waitKey(1) == 13 or count == 200:
        break

cam.release()
cv2.destroyAllWindows()

# %%
#                                                training the model
import cv2
import os
import numpy as np
from PIL import Image

recognizer = cv2.face.LBPHFaceRecognizer_create()
detector = cv2.CascadeClassifier("haarcascade_frontalface_default.xml");

def getImagesAndLabels(path):
    imagePaths = [os.path.join(path,f) for f in os.listdir(path)] 
    faceSamples=[]
    ids = []
    for imagePath in imagePaths:
        PIL_img = Image.open(imagePath).convert('L')
        img_numpy = np.array(PIL_img,'uint8')
        id = int(os.path.split(imagePath)[-1].split(".")[1])
        faces = detector.detectMultiScale(img_numpy)
        for (x,y,w,h) in faces:
            faceSamples.append(img_numpy[y:y+h,x:x+w])
            ids.append(id)
    return faceSamples,ids


faces,ids = getImagesAndLabels('C:/Users/manoj/LW_MLOpps/TASKS/task_6/Training_data/')
recognizer.train(faces, np.array(ids))
recognizer.write('test.pkl')

# %%
#                                       running the model...............................

import cv2
import os
recognizer = cv2.face.LBPHFaceRecognizer_create()
recognizer.read('test.pkl')
faceCascade = cv2.CascadeClassifier("haarcascade_frontalface_default.xml");
cam = cv2.VideoCapture(1
                      )
id1_send_count = 1
id2_send_count = 1
while True:
    ret, im =cam.read()
    gray = cv2.cvtColor(im,cv2.COLOR_BGR2GRAY)
    faces = faceCascade.detectMultiScale(gray, 1.2,5) 
    for(x,y,w,h) in faces:
        cv2.rectangle(im, (x-20,y-20), (x+w+20,y+h+20), (0,255,0), 4)
        Id, confidence = recognizer.predict(gray[y:y+h,x:x+w])  

        if Id == 1:
            Id = "hey! Manoj"
            if id1_send_count == 1:
                import smtplib
                from email.message import EmailMessage

                import cv2
                cap=cv2.VideoCapture(1)
                ret,photo=cap.read()
                cv2.imwrite("a.jpg",photo)
                #cap.release()

                msg=EmailMessage()
                msg['Subject']='Demo Email'
                msg['From']='Manoj Security team'
                msg['To']='tripathimanoj220@gmail.com'
                msg.set_content('Hi this mail from manoj security team')

                with open('a.jpg','rb') as f:
                    file_data=f.read()
                    file_name=f.name
                    msg.add_attachment(file_data,maintype="application",subtype='jpg',filename=file_name)

                server=smtplib.SMTP_SSL('smtp.gmail.com',465)
                server.login("mllwmanoj@gmail.com","redhat@#11")
                server.send_message(msg)
                server.quit()
                
                print("mail sent...........")
                
                 # ------------------------------------------- to send whatsapp message......................
                import pywhatkit
                pywhatkit.sendwhatmsg_instantly('+918279458227','alert! someone found on cam')
            
                print("msg send on whatsapp ")    # selium.............
             
#             break
         
#         else:
            
#             cv2.putText(image, "I dont know, how r u", (250, 450), cv2.FONT_HERSHEY_COMPLEX, 1, (0,0,255), 2)
#             cv2.imshow('Face Recognition', image )  
#             id1_send_count = 0

        
        
        elif Id == 2 and 1 :
            Id = "hey! Deepak"    
            if id2_send_count == 1:

                import subprocess
                import json

                instance = json.loads(subprocess.getoutput('aws ec2 run-instances --image-id ami-0ad704c126371a549 --count 1 --instance-type t2.micro --key-name lwsummer21 --security-group-ids sg-09d428779d9c13d47'))
                az = instance['Instances'][0]['Placement']['AvailabilityZone']
                insid = instance['Instances'][0]['InstanceId']
                ebs = json.loads(subprocess.getoutput('aws ec2 create-volume --volume-type gp2 --size 5 --availability-zone {0}'.format(az)))
                vid = ebs['VolumeId']
                attach = subprocess.getoutput('aws ec2 attach-volume --volume-id {0} --instance-id {1} --device /dev/sdf'.format(vid,insid))
                print("Instance created and 5 GB EBS Volume Attached")
                    
                
               
        else:
            pass

        cv2.rectangle(im, (x-22,y-90), (x+w+22, y-22), (0,255,0), -1)
        cv2.putText(im, str(Id), (x,y-40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 3)

    cv2.imshow('im',im) 

    if cv2.waitKey(1000) == 13:
        break

cam.release()
cv2.destroyAllWindows()
# Out:
# Instance created and 5 GB EBS Volume Attached
# Instance created and 5 GB EBS Volume Attached
# Instance created and 5 GB EBS Volume Attached
# Instance created and 5 GB EBS Volume Attached
# Instance created and 5 GB EBS Volume Attached

# %%
cam.release()
cv2.destroyAllWindows()

# %%
cam.release()
